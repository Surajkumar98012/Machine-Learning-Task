# %% [markdown]
# # Author-Suraj Kumar

# %% [markdown]
# # Decision Tree - Train and Visualize

# %% [markdown]
# # Task3-Prediction using Decision Tree Algorithm

# %% [markdown]
# ● Create the Decision Tree classifier and visualize it graphically.
#
# ● The purpose is if we feed any new data to this classifier, it would be able to predict the right class accordingly.

# %% [markdown]
# # Import Libraries:

# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
import seaborn as sns

# %%
#Filtering the warnings

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the dataset

# %%
iris = datasets.load_iris()

# %%
data=pd.DataFrame(iris['data'],columns=["Petal length","Petal Width","Sepal Length","Sepal Width"])

# %% [markdown]
# Creating a new column “Species” with target values from the dataset, I am using lambda function to apply a function so as to convert the target values which are 0,1,2 to the corresponding target values(“setosa”,”versicolor”,”virginica”)

# %%
data['Species']=iris['target']

# %%
data['Species']=data['Species'].apply(lambda x: iris['target_names'][x])

# %%
data.head()
# Out:
#    Petal length  Petal Width  Sepal Length  Sepal Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(data, hue = 'Species')
plt.show()

# %% [markdown]
# We can easily observe that "iris-setosa" makes a distinctive cluster in every parameter, while the other two species are overlapping a bit on each other

# %% [markdown]
# # Let's check correlation using heatmap

# %%
plt.figure(figsize=(10,11))
sns.heatmap(data.corr(),annot=True)
plt.plot()
# Out:
# []

# %% [markdown]
# Observations made -
#
# 1)Petal length is highly related to petal width.
#
# 2)Sepal lenth is not related sepal width.

# %% [markdown]
# # Let's see that how the categorical feature “Species” is distributed with all other four input variables.

# %%
plt.figure(figsize=(12,10))
plt.subplot(2,2,1)
sns.boxplot(x="Species",y="Sepal Length",data=data)
plt.subplot(2,2,2)
sns.boxplot(x="Species",y="Sepal Width",data=data)
plt.subplot(2,2,3)
sns.boxplot(x="Species",y="Petal length",data=data)
plt.subplot(2,2,4)
sns.boxplot(x="Species",y="Petal Width",data=data)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Petal Width'>

# %% [markdown]
# # Preparing the data for Model Building

# %%
from sklearn.model_selection import train_test_split

train,test=train_test_split(data,test_size=0.3)
train_X=train[['Sepal Length',"Sepal Width","Petal length","Petal Width"]]
train_y=train.Species
test_X=test[['Sepal Length',"Sepal Width","Petal length","Petal Width"]]
test_y=test.Species

# %% [markdown]
# # Importing Decision Tree from Sklearn to build a classification model

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier(random_state=12)
model = DT.fit(train_X, train_y)
DT.predict(test_X)
# Out:
# array(['versicolor', 'versicolor', 'setosa', 'setosa', 'virginica',
#        'setosa', 'setosa', 'setosa', 'versicolor', 'setosa', 'versicolor',
#        'virginica', 'virginica', 'versicolor', 'setosa', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'virginica', 'setosa', 'versicolor', 'virginica', 'setosa',
#        'virginica', 'setosa', 'virginica', 'setosa', 'versicolor',
#        'versicolor', 'versicolor', 'setosa', 'setosa', 'virginica',
#        'virginica', 'versicolor', 'setosa', 'versicolor', 'setosa',
#        'versicolor', 'setosa', 'versicolor', 'virginica', 'setosa'],
#       dtype=object)

# %%
#accuracy check
DT.score(test_X, test_y)
# Out:
# 0.9555555555555556

# %%
#prediction
y_pred = DT.predict(test_X)

# %%
#Accuracy
from sklearn import metrics
print('Accuracy Score:', metrics.accuracy_score(test_y, y_pred))
# Out:
# Accuracy Score: 0.9555555555555556

# %%
pip install dtreeviz
# Out:
# Collecting dtreeviz
#   Downloading dtreeviz-1.3.5.tar.gz (61 kB)
# Requirement already satisfied: graphviz>=0.9 in c:\users\lenovo\anaconda3\lib\site-packages (from dtreeviz) (0.20)
# Requirement already satisfied: pandas in c:\users\lenovo\anaconda3\lib\site-packages (from dtreeviz) (1.3.4)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (from dtreeviz) (1.20.3)
# Requirement already satisfied: scikit-learn in c:\users\lenovo\anaconda3\lib\site-packages (from dtreeviz) (0.24.2)
# Requirement already satisfied: matplotlib in c:\users\lenovo\anaconda3\lib\site-packages (from dtreeviz) (3.4.3)
# Collecting colour
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pytest in c:\users\lenovo\anaconda3\lib\site-packages (from dtreeviz) (6.2.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (3.0.4)
# Requirement already satisfied: six in c:\users\lenovo\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->dtreeviz) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas->dtreeviz) (2021.3)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pytest->dtreeviz) (21.2.0)
# Requirement already satisfied: iniconfig in c:\users\lenovo\anaconda3\lib\site-packages (from pytest->dtreeviz) (1.1.1)
# Requirement already satisfied: packaging in c:\users\lenovo\anaconda3\lib\site-packages (from pytest->dtreeviz) (21.0)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in c:\users\lenovo\anaconda3\lib\site-packages (from pytest->dtreeviz) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pytest->dtreeviz) (1.10.0)
# Requirement already satisfied: toml in c:\users\lenovo\anaconda3\lib\site-packages (from pytest->dtreeviz) (0.10.2)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pytest->dtreeviz) (1.4.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from pytest->dtreeviz) (0.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn->dtreeviz) (2.2.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn->dtreeviz) (1.7.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn->dtreeviz) (1.1.0)
# Building wheels for collected packages: dtreeviz
#   Building wheel for dtreeviz (setup.py): started
#   Building wheel for dtreeviz (setup.py): finished with status 'done'
#   Created wheel for dtreeviz: filename=dtreeviz-1.3.5-py3-none-any.whl size=67331 sha256=ed78b07474ea211776bf0570d444447b04aad8f5143bad080ed36817f11e3c18
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\ec\d8\60\cc047c3ad99fecefdac50c9f4fba8f5865d159c41f583f1f52
# Successfully built dtreeviz
# Installing collected packages: colour, dtreeviz
# Successfully installed colour-0.1.5 dtreeviz-1.3.5
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # As the model is now ready, moving ahead for the visualization of the Decision Tree

# %%
# Import necessary libraries for graph viz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# Visualize the graph
dot_data = StringIO()
export_graphviz(DT, out_file=dot_data, feature_names=iris.feature_names,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# ![download.png](attachment:download.png)
